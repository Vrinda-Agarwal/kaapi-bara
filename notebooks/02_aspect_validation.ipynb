# %% [markdown]
# # 02 Aspect validation
# Run `make aspects` first.

# %%
import pandas as pd
f1 = pd.read_csv('../reports/results/extractor_f1.csv')
f1.pivot(index='flag', columns='extractor', values='f1')

# %%
from IPython.display import Image
Image('../reports/figures/ppi_prevalence.png')
