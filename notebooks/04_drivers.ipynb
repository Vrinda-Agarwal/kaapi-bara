# %% [markdown]
# # 04 Associations
# Associations only, not causal effects. Run `make explain` first.

# %%
import json, pandas as pd
json.load(open('../reports/results/hypotheses.json'))

# %%
pd.read_csv('../reports/results/associations_coefficients.csv')

# %%
from IPython.display import Image
Image('../reports/figures/associations.png')
