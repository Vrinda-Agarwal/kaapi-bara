# %% [markdown]
# # 03 Prediction
# Run `make train` first.

# %%
import pandas as pd
pd.read_csv('../reports/results/prediction_results.csv')

# %%
from IPython.display import Image
display(Image('../reports/figures/reliability.png'), Image('../reports/figures/shap_m3.png'))
