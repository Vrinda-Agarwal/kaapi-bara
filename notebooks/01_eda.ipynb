# %% [markdown]
# # 01 EDA
# Calls project functions only. Run `make data report` first.

# %%
from cafe_reviews.viz.eda import summary
summary()

# %%
from IPython.display import Image
Image('../reports/figures/eda_ratings.png')
